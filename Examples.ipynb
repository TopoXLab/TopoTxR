# %%
# %run Archpool.ipynb
# %run Argparser.ipynb
# %run FileIO.ipynb
# %run CNN.ipynb

settings    = return_settings()
parser      = Argparser(settings)
general     = return_general(0)
arch1       = return_arch(15)
arch2       = return_arch(16)
data_params = return_data_settings(0)

cnn = CNN(general, [arch1, arch2])
cnn.train(data_params)
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# Image shape: (256, 256, 256)
# Image value range: 1.00 - 195.09
# Image data type<class 'numpy.float64'>
# Test mode in data fetcher.
# Image shape: (256, 256, 256)
# Image value range: 1.00 - 205.68
# Image data type<class 'numpy.float64'>
# Test mode in data fetcher.
# [0/2000][19/65] loss: 2.6714 Step: 20
# (32,)
# Test accurady: 0.4688  Balanced_accuracy: 0.4500
# Specificity: 0.1667  Sensitivity: 0.6500
# AUC: 0.4083
# F1 score: 0.1905
# Best F1 score: -1.0000  Step: 0
# [0/2000][39/65] loss: 5.8779 Step: 40
# (32,)
# Test accurady: 0.4688  Balanced_accuracy: 0.4167
# Specificity: 0.0000  Sensitivity: 0.7500
# AUC: 0.3750
# F1 score: 0.0000
# Best F1 score: -1.0000  Step: 0
# [0/2000][59/65] loss: 8.9855 Step: 60
# (32,)
# Test accurady: 0.6562  Balanced_accuracy: 0.6333
# Specificity: 0.3333  Sensitivity: 0.8500
# AUC: 0.5917
# F1 score: 0.4211
# Best F1 score: -1.0000  Step: 0
# [1/2000][15/65] loss: 7.9859 Step: 80
# (32,)
# Test accurady: 0.3125  Balanced_accuracy: 0.4083
# Specificity: 0.5833  Sensitivity: 0.1500
# AUC: 0.3667
# F1 score: 0.3889
# Best F1 score: -1.0000  Step: 0
# [1/2000][35/65] loss: 9.0330 Step: 100
# (32,)
# Test accurady: 0.5625  Balanced_accuracy: 0.5083
# Specificity: 0.0833  Sensitivity: 0.8500
# AUC: 0.4667
# F1 score: 0.1250
# Best F1 score: -1.0000  Step: 0
# [1/2000][55/65] loss: 2.8239 Step: 120
# (32,)
# Test accurady: 0.5312  Balanced_accuracy: 0.5500
# Specificity: 0.4167  Sensitivity: 0.6000
# AUC: 0.5083
# F1 score: 0.4000
# Best F1 score: -1.0000  Step: 0
# [2/2000][11/65] loss: 4.3389 Step: 140
# (32,)
# Test accurady: 0.5938  Balanced_accuracy: 0.6167
# Specificity: 0.5000  Sensitivity: 0.6500
# AUC: 0.5750
# F1 score: 0.4800
# Best F1 score: -1.0000  Step: 0
# [2/2000][31/65] loss: 1.9459 Step: 160
# (32,)
# Test accurady: 0.5000  Balanced_accuracy: 0.5083
# Specificity: 0.3333  Sensitivity: 0.6000
# AUC: 0.4667
# F1 score: 0.3333
# Best F1 score: -1.0000  Step: 0
# [2/2000][51/65] loss: 2.8361 Step: 180
# (32,)
# Test accurady: 0.5312  Balanced_accuracy: 0.5333
# Specificity: 0.3333  Sensitivity: 0.6500
# AUC: 0.4917
# F1 score: 0.3478
# Best F1 score: -1.0000  Step: 0
# [3/2000][7/65] loss: 2.2167 Step: 200
# (32,)
# Test accurady: 0.6250  Balanced_accuracy: 0.5417
# Specificity: 0.0000  Sensitivity: 1.0000
# AUC: 0.5000
# F1 score: 0.0000
# Best F1 score: -1.0000  Step: 0
# [3/2000][27/65] loss: 2.9739 Step: 220
# (32,)
# Test accurady: 0.5000  Balanced_accuracy: 0.4917
# Specificity: 0.2500  Sensitivity: 0.6500
# AUC: 0.4500
# F1 score: 0.2727
# Best F1 score: -1.0000  Step: 0
# [3/2000][47/65] loss: 1.5871 Step: 240
# (32,)
# Test accurady: 0.5312  Balanced_accuracy: 0.5000
# Specificity: 0.1667  Sensitivity: 0.7500
# AUC: 0.4583
# F1 score: 0.2105
# Best F1 score: -1.0000  Step: 0
# [4/2000][3/65] loss: 1.2505 Step: 260
# (32,)
# Test accurady: 0.6562  Balanced_accuracy: 0.6667
# Specificity: 0.5000  Sensitivity: 0.7500
# AUC: 0.6250
# F1 score: 0.5217
# Best F1 score: -1.0000  Step: 0
# [4/2000][23/65] loss: 1.6403 Step: 280
# (32,)
# Test accurady: 0.6250  Balanced_accuracy: 0.5583
# Specificity: 0.0833  Sensitivity: 0.9500
# AUC: 0.5167
# F1 score: 0.1429
# Best F1 score: -1.0000  Step: 0
# [4/2000][43/65] loss: 1.7273 Step: 300
# (32,)
# Test accurady: 0.4375  Balanced_accuracy: 0.4417
# Specificity: 0.2500  Sensitivity: 0.5500
# AUC: 0.4000
# F1 score: 0.2500
# Best F1 score: -1.0000  Step: 0
# [4/2000][63/65] loss: 1.5322 Step: 320
# (32,)
# Test accurady: 0.6250  Balanced_accuracy: 0.5417
# Specificity: 0.0000  Sensitivity: 1.0000
# AUC: 0.5000
# F1 score: 0.0000
# Best F1 score: -1.0000  Step: 0
# [5/2000][19/65] loss: 1.2734 Step: 340
# (32,)
# Test accurady: 0.6562  Balanced_accuracy: 0.5833
# Specificity: 0.0833  Sensitivity: 1.0000
# AUC: 0.5417
# F1 score: 0.1538
# Best F1 score: -1.0000  Step: 0
# [5/2000][39/65] loss: 1.3518 Step: 360
# (32,)
# Test accurady: 0.5312  Balanced_accuracy: 0.4667
# Specificity: 0.0000  Sensitivity: 0.8500
# AUC: 0.4250
# F1 score: 0.0000
# Best F1 score: -1.0000  Step: 0
# [5/2000][59/65] loss: 1.3259 Step: 380
